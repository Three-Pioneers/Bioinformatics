# %%
a = "..."
string = ''
for i in a:
	if i == "A":
		string += "T"
	elif i == "T":
		string += "A"
	elif i == "G":
		string += "C"
	else:
		string += "G"
b = ''
for n in range(len(string)):
	b += string[len(string)-1-n]
b
# Out:
# '...'

# %%
reverse_string = ''
n = 0
range(len(string))
for i in range(len(string)-1,-1,-1):
	reverse_string += string[i]
reverse_string
# Out:
# 'ACCGGGTTTT'

# %%
string[::-1]
# Out:
# '...'

# %%
print(''.join(reversed(string)))
# Out:
# ACCGGGTTTT
