# %%
a = "..."
A = 0
C = 0
G = 0
T = 0
for i in a:
	if i == "A":
		A += 1
	elif i == "C":
		C += 1
	elif i == "G":
		G += 1
	else:
		T += 1
print("A 的个数是：",A)
print("C 的个数是：",C)
print("G 的个数是：",G)
print("T 的个数是：",T)

# %%
print(a.count("A"), a.count("C"), a.count("G"), a.count("T"))
