# %%
import sys

file = sys.argv[1]

e = 0
f = ''
with open(file, "r") as FR:
	fr = FR.read()
	a = fr.split(">")[1:]
	for i in a:
		b = i.split('\n', 1)
		c = b[0]
		d = b[1].replace('\n', '')
		rate = (d.count("G") + d.count("C")) / len(d) * 100
		
		if rate > e:
			e = rate
			f = c
			h = d
	print(f)
	print(e)
	print(d)

# %%
a = 'arfadf\n\n\n'
a
a.replace("\n","")
# Out:
# 'arfadf'
