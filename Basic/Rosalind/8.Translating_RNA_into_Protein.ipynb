# %%
with open("RNA_code_table.txt", "r") as FR:
	fr = FR.readlines()
dict1 = {}
for i in fr:
	a = i.strip().split("  ")
	for j in a:
		b = j.split(" ")
		dict1[b[0]] = b[1]

# %%
string1 = "..."
string2 = ""
n = len(string1) // 3
for i in range(n):
	c = string1[3*i:3*i+3]
	if dict1[c] == "Stop":
		break
	else:
		string2 += dict1[c]

string2
