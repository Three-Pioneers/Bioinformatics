# %% [markdown]
# ## 读取文本文件

# %%
import pandas as pd

# %%
he = pd.read_csv(
    "/home/zhangxuejie/Bioinformatics/hehe.txt",
    sep="\t",
    header=0    # header=None：无表头；header=[0,1]：两行表头
    # names=["a", "b", "c"] 自定义列名，需要和列数匹配
)

# %%
he.head()   # 前五行

# %%
he.shape    # 数据形状属性，返回行数、列数

# %%
he.columns

# %%
he.index

# %%
he.dtypes

# %% [markdown]
# ## 读取 office 表格

# %%
b = pd.read_excel("")   # 读取 xls xlsx

# %% [markdown]
# ## 读取 mysql 数据库
